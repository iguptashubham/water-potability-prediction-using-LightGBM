# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
clf_transformation = ColumnTransformer(
        transformers=[
            ('[ph]',MinMaxScaler(),[0]),
            ("""Hardness, Solids, 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity""",StandardScaler,[1,2,3,4,5,6,7,8]),
        ],remainder='passthrough'
    )

# %%
clf_transformation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:699, in BaseEstimator._repr_mimebundle_(self, **kwargs)
#     697 output = {"text/plain": repr(self)}
#     698 if get_config()["display"] == "diagram":
# --> 699     output["text/html"] = estimator_html_repr(self)
#     700 return output
#
# ...

# %%
from pathlib import Path

# Initialize paths as an empty tuple
paths = ()

# Define raw_path as a Path object
raw_path = Path('x')

# Create paths for test and train CSV files
test_path = raw_path / 'test' / 'test.csv'
train_path = raw_path / 'train' / 'train.csv'

# Add the paths to the tuple
paths = paths + (test_path, train_path)

# Print the paths
print(paths)
# Out:
# (WindowsPath('x/test/test.csv'), WindowsPath('x/train/train.csv'))

# %%
data = (r'C:\Users\gupta\OneDrive\Desktop\Projects\lightgbm\water_potability\data\raw\water-potability.csv')

process_data(df_path=data)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.036752  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.073546
# 2     8.099124  224.236259  19909.541732     9.275884  333.073546
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.073546
# 3273  9.419510  175.762646  33155.578218     7.350233  333.073546
# 3274  5.126763  230.603758  11983.869376     6.303357  333.073546
# 3275  7.874671  195.102299  17404.177061     7.509306  333.073546
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
df['ph'].median()
# Out:
# 7.036752103833548
